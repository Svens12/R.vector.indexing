# %%
x<-c(10,45,30,50,35,40,80)

# %%
x[1]
# Out:
# [1] 10

# %%
x[-2]
# Out:
# [1] 10 30 50 35 40 80

# %%
x[3:7]
# Out:
# [1] 30 50 35 40 80

# %%
x[c(1,3,4)]
# Out:
# [1] 10 30 50

# %%
length(x)
# Out:
# [1] 7

# %%
x[10]
# Out:
# [1] NA

# %%
x<-c(10,45,30,50,35,40,80)
x[2]<--8

# %%
x
# Out:
# [1] 10 -8 30 50 35 40 80

# %%
x<-c(10,45,30,50,35,40,80)
x[10]<-8

# %%
x
# Out:
#  [1] 10 45 30 50 35 40 80 NA NA  8

# %%
x<-c(10,45,30,50,35,40,80)
x[-3]<-8

# %%
x
# Out:
# [1]  8  8 30  8  8  8  8

# %%
x<-c(10,45,30,50,35,40,80)
y<-c(TRUE,FALSE,TRUE,TRUE,FALSE,TRUE,FALSE)

# %%
x[y]
# Out:
# [1] 10 30 50 40

# %%
x<-c(10,45,30,50,35,40,80)
y<-c(T,F,T)
x[y]
# Out:
# [1] 10 30 50 40 80

# %%
x<-c(10,45,30,50,35,40,80)
for(i in 1:length(x))
    print(x[i])
# Out:
# [1] 10
# [1] 45
# [1] 30
# [1] 50
# [1] 35
# [1] 40
# [1] 80

# %%
x<-c(10,45,30,50,35,40,80)
for(i in 1:7)
    print(x[i])
# Out:
# [1] 10
# [1] 45
# [1] 30
# [1] 50
# [1] 35
# [1] 40
# [1] 80

# %%
x<-c(10,45,30,50,35,40,80)
for(i in 1:10)
    print(x[i])
# Out:
# [1] 10
# [1] 45
# [1] 30
# [1] 50
# [1] 35
# [1] 40
# [1] 80
# [1] NA
# [1] NA
# [1] NA

# %%
x<-c(10,45,30,50,35,40,80)
for(i in seq_along(x))
    print(x[i])
# Out:
# [1] 10
# [1] 45
# [1] 30
# [1] 50
# [1] 35
# [1] 40
# [1] 80

# %%
x<-c(10,45,30,50,35,40,80)
for(i in x)
    print(i)
# Out:
# [1] 10
# [1] 45
# [1] 30
# [1] 50
# [1] 35
# [1] 40
# [1] 80
